# %% [markdown]
# Data types - integers and String

# %% [markdown]
# 3  - integer  and a,b,c, vanya, aerplane - strings

# %%
print(type(3))
# Out:
# <class 'int'>

# %%
print(type(490932049820942))
# Out:
# <class 'int'>

# %%
print('vanya')
# Out:
# vanya

# %%
print(type('vanya'))
# Out:
# <class 'str'>

# %%
print(type(4.00))
# Out:
# <class 'float'>

# %%
print(type('True'))
# Out:
# <class 'str'>

# %% [markdown]
# Wr write string aka letter inside the quotes

# %%
print(type(True))
# Out:
# <class 'bool'>

# %% [markdown]
# Boolean either true or false

# %%
# We can just add same types of data types

# %%
a = 3+3
print(a)
# Out:
# 6

# %%
print(67+90)
# Out:
# 157

# %%
a = 'banana'+'mango'
print(a)
# Out:
# bananamango

# %%
print('car'+''+'Train')
# Out:
# carTrain

# %%
print(3 +'banana') # different datatypes gives error when we perform some operations on it, but there are some expections too
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_227424/1330126667.py in <module>
# ----> 1 print(3+'banana') # different datatypes gives error when we perform some operations on it, but there are some expections too
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(type(-2))
# Out:
# <class 'int'>

# %%
print(type(-2.1)) # decimal is known as float
# Out:
# <class 'float'>

# %%
print(2+4.56) #2.00+4.56  this is exception
# Out:
# 6.56

# %%
# addtion  +  , subtraction   - ,  multiplication *

# %%
# Division /   and Floor division //

# %%
print(3/2)
# Out:
# 1.5

# %%
print(4/2)
# Out:
# 2.0

# %%
print(90/5)
# Out:
# 18.0

# %%
# the divison or the normal divison always gives us float value

# %%
print(90.0/5.0)
# Out:
# 18.0

# %%
print(3.4/2)
# Out:
# 1.7

# %%
# floor divison

# %%
print(5//2) # 5/2 = 2.5
# Out:
# 2

# %%
print(7//2) # 7/2 - 3.5
# Out:
# 3

# %%
print(21/9)
# Out:
# 2.3333333333333335

# %%
print(21//9)
# Out:
# 2

# %%
print(21/4)
# Out:
# 5.25

# %%
print(21/6)
# Out:
# 3.5

# %%
print(21/8)
# Out:
# 2.625

# %%
print(21//8)
# Out:
# 2

# %%
# floor divison always rounds off the value towards the lower side, even if it is 2.999999 it will give 2

# %%
# modulo divison - %   basically it gives us remainder

# %%
print(3%2)
# Out:
# 1

# %%
print(48%7)
# Out:
# 6

# %%
#powers **

# %%
print(2**2) # 2*2
# Out:
# 4

# %%
print(2**3) # 2*2*2
# Out:
# 8

# %%
print(3*2) # 3*3
# Out:
# 6

# %%
 print(87**9045)
# Out:
# ...

# %%
print(8*6)
# Out:
# 48

# %%
# bodmas --- bracket open division multiplication additoion and substraction

# %%
a = 2*2 +4 +3/2
print(a)
# Out:
# 9.5

# %%
# not to do in python 
1 = 289
1=  'acbc'

sun flower = 'vanya'

sun_flower = 'vanya'
# Out:
#   File "/tmp/ipykernel_227424/1969301675.py", line 2
#     1 = 289
#     ^
# SyntaxError: cannot assign to literal
